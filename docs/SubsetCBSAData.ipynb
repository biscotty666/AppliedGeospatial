# %% [markdown]
# # Partial import of data
#
# https://www2.census.gov/geo/tiger/TIGER2024/CBSA/
# https://www2.census.gov/geo/tiger/TIGER2024/STATE/

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
us_states = gpd.read_file('../data/CA_CBSAs/tl_2024_us_state.zip')

# %%
us_states.head(2)
# Out:
#   REGION DIVISION STATEFP   STATENS GEOID      GEOIDFQ STUSPS           NAME  \
# 0      3        5      54  01779805    54  0400000US54     WV  West Virginia
# 1      3        5      12  00294478    12  0400000US12     FL        Florida
#
#   LSAD  MTFCC FUNCSTAT         ALAND       AWATER     INTPTLAT      INTPTLON  \
# 0   00  G4000        A   62266513826    488918898  +38.6472854  -080.6183274
# 1   00  G4000        A  138965379385  45968913048  +28.3989775  -082.5143005
#
#                                             geometry
# 0  POLYGON ((-77.75438 39.33346, -77.75422 39.333...
# 1  MULTIPOLYGON (((-83.10874 24.62949, -83.10711 ...

# %%
nm = us_states[us_states.NAME == 'New Mexico']
nm.head()
# Out:
#    REGION DIVISION STATEFP   STATENS GEOID      GEOIDFQ STUSPS        NAME  \
# 12      4        8      35  00897535    35  0400000US35     NM  New Mexico
#
#    LSAD  MTFCC FUNCSTAT         ALAND     AWATER     INTPTLAT      INTPTLON  \
# 12   00  G4000        A  314198519809  726531289  +34.4346843  -106.1316181
#
#                                              geometry
# 12  POLYGON ((-103.06472 32.33465, -103.0647 32.33...

# %%
nm_cbsas = gpd.read_file('../data/CA_CBSAs/tl_2024_us_cbsa.zip', 
                        mask=nm)
nm_cbsas.head()
# Out:
#   CSAFP CBSAFP  GEOID         GEOIDFQ                  NAME  \
# 0  None  40740  40740  310M700US40740           Roswell, NM
# 1  None  40760  40760  310M700US40760           Ruidoso, NM
# 2  None  16100  16100  310M700US16100  Carlsbad-Artesia, NM
# 3  None  17580  17580  310M700US17580            Clovis, NM
# 4   105  42140  42140  310M700US42140          Santa Fe, NM
#
#                           NAMELSAD LSAD MEMI  MTFCC        ALAND    AWATER  \
# 0           Roswell, NM Micro Area   M2    2  G3110  15713917209  20469858
# 1           Ruidoso, NM Micro Area   M2    2  G3110  12512530052    554839
# 2  Carlsbad-Artesia, NM Micro Area   M2    2  G3110  10816692054  56489010
# 3            Clovis, NM Micro Area   M2    2  G3110   9975532777  26672616
# 4          Santa Fe, NM Metro Area   M1    1  G3110   4947861289   2643021
#
#       INTPTLAT      INTPTLON  \
# 0  +33.3616045  -104.4698374
# 1  +33.7408411  -105.4498055
# 2  +32.4578347  -104.3064338
# ...

# %%
b_box = (-109.050173, 31.332301, -103.001964, 37.000232)
nmsas_bbox = gpd.read_file('../data/CA_CBSAs/tl_2024_us_cbsa.zip', 
                          bbox=b_box)
nmsas_bbox.head()
# Out:
#   CSAFP CBSAFP  GEOID         GEOIDFQ                  NAME  \
# 0  None  40740  40740  310M700US40740           Roswell, NM
# 1  None  40760  40760  310M700US40760           Ruidoso, NM
# 2  None  16100  16100  310M700US16100  Carlsbad-Artesia, NM
# 3  None  17580  17580  310M700US17580            Clovis, NM
# 4   105  42140  42140  310M700US42140          Santa Fe, NM
#
#                           NAMELSAD LSAD MEMI  MTFCC        ALAND    AWATER  \
# 0           Roswell, NM Micro Area   M2    2  G3110  15713917209  20469858
# 1           Ruidoso, NM Micro Area   M2    2  G3110  12512530052    554839
# 2  Carlsbad-Artesia, NM Micro Area   M2    2  G3110  10816692054  56489010
# 3            Clovis, NM Micro Area   M2    2  G3110   9975532777  26672616
# 4          Santa Fe, NM Metro Area   M1    1  G3110   4947861289   2643021
#
#       INTPTLAT      INTPTLON  \
# 0  +33.3616045  -104.4698374
# 1  +33.7408411  -105.4498055
# 2  +32.4578347  -104.3064338
# ...

# %% [markdown]
# >US State Bounding Boxes
#
# [Website](https://anthonylouisdagostino.com/bounding-boxes-for-all-us-states/)
#
# -109.050173 | 31.332301 | -103.001964 | 37.000232 |

# %%
import us

# %%
us.states.NM.shapefile_urls()
# Out:
# {'tract': 'https://www2.census.gov/geo/tiger/TIGER2010/TRACT/2010/tl_2010_35_tract10.zip',
#  'cd': 'https://www2.census.gov/geo/tiger/TIGER2010/CD/111/tl_2010_35_cd111.zip',
#  'county': 'https://www2.census.gov/geo/tiger/TIGER2010/COUNTY/2010/tl_2010_35_county10.zip',
#  'state': 'https://www2.census.gov/geo/tiger/TIGER2010/STATE/2010/tl_2010_35_state10.zip',
#  'zcta': 'https://www2.census.gov/geo/tiger/TIGER2010/ZCTA5/2010/tl_2010_35_zcta510.zip',
#  'block': 'https://www2.census.gov/geo/tiger/TIGER2010/TABBLOCK/2010/tl_2010_35_tabblock10.zip',
#  'blockgroup': 'https://www2.census.gov/geo/tiger/TIGER2010/BG/2010/tl_2010_35_bg10.zip'}

# %%
state_nm = gpd.read_file("https://www2.census.gov/geo/tiger/TIGER2010/COUNTY/2010/tl_2010_35_county10.zip")

# %%
state_nm.columns
# Out:
# Index(['STATEFP10', 'COUNTYFP10', 'COUNTYNS10', 'GEOID10', 'NAME10',
#        'NAMELSAD10', 'LSAD10', 'CLASSFP10', 'MTFCC10', 'CSAFP10', 'CBSAFP10',
#        'METDIVFP10', 'FUNCSTAT10', 'ALAND10', 'AWATER10', 'INTPTLAT10',
#        'INTPTLON10', 'geometry'],
#       dtype='object')

# %%
state_nm.plot()
# Out:
# <Axes: >

# %%
state_nm.union_all().boundary
# Out:
# <LINESTRING (-109.049 31.959, -109.049 31.964, -109.049 31.965, -109.049 31....>

# %%
state_nm.union_all().bounds
# Out:
# (-109.050173, 31.332172, -103.001964, 37.000293)

# %%
f, ax = plt.subplots(figsize=(10,10))
nm_cbsas.plot(ax=ax);

# %%
state_nm.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# ...

# %%
nm_cbsas.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# ...

# %%
nm_cbsas.union_all().bounds
# Out:
# (-110.460916, 30.629258, -101.03839, 37.752306)

# %%
state_nm.union_all().bounds
# Out:
# (-109.050173, 31.332172, -103.001964, 37.000293)

# %%
nm.union_all().bounds
# Out:
# (-109.050431, 31.33216, -103.002043, 37.000233)

# %%
bbox = nm.union_all().bounds
nm_cbsas = gpd.read_file('../data/CA_CBSAs/tl_2024_us_cbsa.zip', 
                        bbox=bbox)

# %%
nm_cbsas.union_all().bounds
# Out:
# (-110.460916, 30.629258, -101.03839, 37.752306)

# %%
f, ax = plt.subplots(figsize=(10,10))
state_nm.plot(ax=ax, color='lightgrey')
nm_cbsas.plot(ax=ax, color='g');
